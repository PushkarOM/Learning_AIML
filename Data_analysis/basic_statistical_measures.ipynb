# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### Basic Statistical Measures Used for Data Analysis
#
# ### Measures of Central Tendency
#
# In statistics, **central tendency** refers to the tendency of quantitative data to cluster around a central value in a probability distribution. In simpler terms, central tendency refers to the tendency of quantitative data to cluster around a central or typical value.
#
# **Mean:**
# The mean is the average value of a dataset, calculated by summing all values and dividing by the total number of values.
#
# $$ \text{Mean} = \frac{\sum_{i=1}^{n} x_i}{n} $$
#
# **Median:**
# The median is the middle value of an ordered dataset. If the number of observations is odd, the median is the middle number. If even, it is the average of the two middle numbers.
#
# **Mode:**
# The mode is the most frequently occurring element in the dataset.
#
# ### Measures of Dispersion
#
# In statistics, **dispersion** describes how spread out or squeezed together a distribution of data is.
#
# **Range:**
# The range is the difference between the largest and smallest values in the dataset.
#
# **Interquartile Range (IQR):**
# The IQR is the range between the first quartile (Q1) and the third quartile (Q3). It measures the spread of the middle 50% of the data.
#
# **Quartiles:**
# Quartiles are a type of quantile that divide the number of data points into four parts. The three quartiles result in four divisions:
#
# - **First Quartile (Q1):** Also known as the lower quartile, it is defined as the 25th percentile where 25% of data is below this point.
# - **Second Quartile (Q2):** This is the median of the dataset, so 50% of data is below this point.
# - **Third Quartile (Q3):** Also known as the upper quartile, it is defined as the 75th percentile where 75% of data is below this point.
#
# **Percentile:**
# Values below which a certain percentage of the data falls.
#
# **Quantiles:**
# Quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities, or dividing the observations in a sample in the same way. There is one fewer quantile than the number of groups created.
#
# **Variance:**
# Variance measures the average squared deviation of each data point from the mean. It is a measure of how far a set of numbers is spread out from their average value.
#
# $$ \text{Variance} (\sigma^2) = \frac{\sum_{i=1}^{n}(x_i - \mu)^2}{n} $$
#
# **Standard Deviation:**
# It is the square root of the variance. It is in the same unit as the data.
#
# $$ \text{Standard Deviation} (\sigma) = \sqrt{\frac{\sum_{i=1}^{n}(x_i - \mu)^2}{n}} $$
#
# ### Measures of Shape
#
# **Skewness:**
# It measures the asymmetry of the data distribution. Positive skewness indicates a longer right tail, while negative skewness indicates a longer left tail.
#
# $$ \text{Skewness} = \frac{n}{(n-1)(n-2)} \sum_{i=1}^{n} \left(\frac{x_i - \mu}{\sigma}\right)^3 $$
#
# **Kurtosis:**
# Kurtosis measures the "tailedness" of the data distribution. High kurtosis indicates heavy tails and sharp peaks, while low kurtosis indicates light tails and flat peaks.
#
# $$ \text{Kurtosis} = \frac{n(n+1)}{(n-1)(n-2)(n-3)} \sum_{i=1}^{n} \left(\frac{x_i - \mu}{\sigma}\right)^4 - \frac{3(n-1)^2}{(n-2)(n-3)} $$
#
# ### Measures of Association
#
# In statistics, **measures of association** are a range of statistical tools that can quantify the strength and direction of relationships between two or more variables.
#
# **Covariance:**
# It is the measure of joint variability of two random variables (how much they vary together).
#
# $$ \text{Cov}(X, Y) = E[XY] - E[X]E[Y] $$
# where E[X] is the mean of X.
#
# **Pearson's Correlation Coefficient (r):**
# It measures the strength and direction of the linear relationship between two variables. The \( R^2 \) measure is derived from this.
#
# $$ r = \frac{\text{Cov}(X, Y)}{\sigma_X \sigma_Y} $$
#
# - Here, $\sigma_X \sigma_Y$ are standered Deviation of X and Y.
#
# #let's now use these on a popular dataset "WINEQUALITY", to see how they help in undestanding data without visualizing it.

# %%
data = pd.read_csv("./data/winequality-white.csv", sep= ";")

# %%
# Let's see the total number of row and colums in our data set
print(data.shape)
data.info() #let's see additional info about the data
# Out:
# (4898, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# #### We have 4898 rows and 12 columns.
# - Most of the values are of float64 type, except one int64.
# - There is no null value i.e missing value in our dataset.
# - Now let's see the first and last 5 values of this dataset.

# %%
data.head() #by default prints starting 5 values
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
data.tail() #by default prints ending 5 values
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %% [markdown]
# #### Out of this 12 coloumns "quality" is our target value i.e the dependent variable. rest are independent variable or input feature.

# %%
#To take a Look at the different statistic measure discussed above we can use pandas "describe()" method
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %% [markdown]
#  #### Above we can see the following:-
#
# **For the Fixed Acidity column:**
#
# - The mean value is 6.854.
# - The standard deviation around the mean value of the data is about 0.84, indicating a relatively higher concentration of data points near the mean     value.
# - The 25th percentile indicates that 25% of the data points are below 6.3.
# - The 50th percentile indicates that 50% of the data points are below 6.8 (this is also the median value).
# - The 75th percentile indicates that 75% of the data points are below 7.3.
# - The above indicates that our dataset is slightly right-skewed or positively skewed as the mean is greater than the 50th percentile.
#
# Further, the IQR gives us a value of 1.0, meaning the middle 50% of the data is in about a 1-unit range, indicating a tight concentration around the center.
# A common rule is that values more than 1.5 times the IQR below Q1 or above Q3 are considered potential outliers.
# $$ \text{lower bound} = Q1 - 1.5*IQR$$
# $$ \text{upper bound} = Q3 + 1.5*IQR$$
#
# - The comparison of the 75th percentile with the maximum value, and the 25th percentile with the minimum value, shows that there are outliers present:
#     - The minimum value (3.8) is significantly lower than the lower bound (4.8), indicating the presence of low outliers.
#     - The maximum value (14.2) is significantly higher than the upper bound (8.8), indicating the presence of high outliers.
#
# Similar, analysis can be applied to each columns to understand how the values behave in them.
#
# **For the Volatile Acidity column:**
# - The standard deviation indicates a relatively tight spread around the mean.
# - The data points in this column are slightly right-skewed as the mean is greater than the median.
# - The IQR shows a tight concentration of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Citric Acid column:**
# - The standard deviation shows a moderate spread around the mean.
# - The data points in this column are slightly right-skewed.
# - The IQR indicates a moderate concentration of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Residual Sugar column:**
# - The standard deviation shows a large spread around the mean.
# - The data points in this column are heavily right-skewed.
# - The IQR shows a significant spread of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Chlorides column:**
# - The standard deviation indicates a relatively tight spread around the mean.
# - The data points in this column are slightly right-skewed.
# - The IQR shows a tight concentration of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Free Sulfur Dioxide column:**
# - The standard deviation indicates a large spread around the mean.
# - The data points in this column are slightly right-skewed.
# - The IQR shows a significant spread of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Total Sulfur Dioxide column:**
# - The standard deviation shows a large spread around the mean.
# - The data points in this column are slightly right-skewed.
# - The IQR shows a significant spread of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Density column:**
# - The standard deviation shows a tight spread around the mean.
# - The data points in this column are slightly right-skewed.
# - The IQR suggests a tight concentration of the middle 50% of the data.
# - Outliers: Yes
#
# **For the pH column:**
# - The standard deviation shows a moderate spread around the mean.
# - The dataset is slightly right-skewed.
# - The IQR shows a moderate concentration of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Sulphates column:**
# - The standard deviation shows a moderate spread around the mean.
# - The dataset is slightly right-skewed.
# - The IQR indicates a moderate concentration of the middle 50% of the data.
# - Outliers: Yes
#
# **For the Alcohol column:**
# - The standard deviation shows a moderate spread around the mean.
# - The dataset is slightly right-skewed.
# - The IQR shows a moderate concentration of the middle 50% of the data.
# - Outliers: No
#
# **For the Quality column:**
# - The standard deviation shows a moderate spread around the mean.
# - The dataset is slightly right-skewed.
# - The IQR indicates a moderate concentration of the middle 50% of the data.
# - Outliers: Yes

# %%
#Taking a look at the quality colums (target value)
data.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
data.quality.value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# We can see that most wines are of quality level 6 implies that this is the most common rating, indicating an average quality level for the majority of the wines.
# The presence of only a few high-quality wines and a bunch of low-quality wines suggests a skewed distribution where high and low ratings are less common compared to the middle range.

# %% [markdown]
# #### We can quantify the Skewness of each distribution to confirm our observation by calculating it's value.

# %%
def calculate_skewness(data):
    """
    Calculate the skewness of a dataset.

    Parameters:
    - data (list or pd.Series): The data for which to calculate skewness.

    Returns:
    - float: The skewness of the data.
    """
    # Convert data to a numpy array if it's a pandas Series
    if isinstance(data, pd.Series): # a function used to check if a object is an instance of a class
        data = data.values

    # Calculate mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data, ddof=0)  # Population standard deviation

    # Calculate skewness
    n = len(data)
    skewness = (n / ((n - 1) * (n - 2))) * np.sum(((data - mean) / std_dev) ** 3)
    
    return skewness

# alrenativly we can use a libray called scipy stats.

# %%
for columns in data.columns:
    print(f'Skewness of {columns}: ', calculate_skewness(data[f'{columns}']))
# Out:
# Skewness of fixed acidity:  0.6479498975036447
# Skewness of volatile acidity:  1.5774625722236126
# Skewness of citric acid:  1.282313083231465
# Skewness of residual sugar:  1.0774236978398457
# Skewness of chlorides:  5.024869457659677
# Skewness of free sulfur dioxide:  1.4071758425442207
# Skewness of total sulfur dioxide:  0.39082952608925625
# Skewness of density:  0.9780725217936713
# Skewness of pH:  0.45792277644156953
# Skewness of sulphates:  0.9774930227702094
# Skewness of alcohol:  0.48749127855571994
# Skewness of quality:  0.15584412215078905

# %% [markdown]
# Skewness values greater than 0 indicate a positively skewed distribution. Skewness values less than 0 indicate a negatively skewed distribution. A skewness value equal to 0 suggests a symmetric distribution.
# (value won't be exaclty equal to 0, so sufficiently low values can be taken as 0)

# %%
#let's now calculate the covarience of each pair of columns
for col1 in data.columns:
    for col2 in data.columns:
        print(f"COV({col1},{col2}):",data[col1].cov(data[col2]))


# We can also implement a fucntion to calculate the cov value
def calc_covariance(data):
    """
        Calculates the Covariance Matrix
    Args:
        data (DataFrame) : dataset
    Returns:
        cov_matrix (dict) : covariance
    """
    # calculating mean of each column
    means = {col: data[col].mean() for col in data.columns}
    
    # Prepare an empty dictionary to store covariance results
    cov_matrix = {}

    # Iterate over all pairs of columns
    for col1 in data.columns:
        for col2 in data.columns:
            # Calculate covariance
            col1Xcol2 = data[col1] * data[col2] # Claculating E[X,Y]
            mean_col1Xcol2 = col1Xcol2.mean() # Finding it's mean
            cov = mean_col1Xcol2 - (means[col1] * means[col2]) # Final COV value
            
            # Store covariance in the dictionary
            cov_matrix[(col1, col2)] = cov
    
    return cov_matrix

# Cov Matirx is nothing but covarience of all possible combination of columns
# Out:
# COV(fixed acidity,fixed acidity): 0.7121135857004641
# COV(fixed acidity,volatile acidity): -0.001930570601679193
# COV(fixed acidity,citric acid): 0.029532511571780048
# COV(fixed acidity,residual sugar): 0.381021813652795
# COV(fixed acidity,chlorides): 0.0004256255361050133
# COV(fixed acidity,free sulfur dioxide): -0.7089186423667687
# COV(fixed acidity,total sulfur dioxide): 3.266013392629699
# COV(fixed acidity,density): 0.000669677255776885
# COV(fixed acidity,pH): -0.05426482595364051
# COV(fixed acidity,sulphates): -0.0016509922909276956
# COV(fixed acidity,alcohol): -0.12553282191892606
# COV(fixed acidity,quality): -0.08494730942928613
# COV(volatile acidity,fixed acidity): -0.001930570601679193
# COV(volatile acidity,volatile acidity): 0.010159540992172523
# COV(volatile acidity,citric acid): -0.0018232775514512808
# COV(volatile acidity,residual sugar): 0.032865333683183506
# COV(volatile acidity,chlorides): 0.000155277485703241
# COV(volatile acidity,free sulfur dioxide): -0.16630045911893623
# COV(volatile acidity,total sulfur dioxide): 0.3823539031238282
# COV(volatile acidity,density): 8.173932688766277e-06
# COV(volatile acidity,pH): -0.00048575309397266787
# COV(volatile acidity,sulphates): -0.0004109902309336311
# COV(volatile acidity,alcohol): 0.00839972308554453
# COV(volatile acidity,quality): -0.01738244046216911
# COV(citric acid,fixed acidity): 0.029532511571780048
# COV(citric acid,volatile acidity): -0.0018232775514512808
# COV(citric acid,citric acid): 0.014645793009328218
# COV(citric acid,residual sugar): 0.05782892645666931
# COV(citric acid,chlorides): 0.00030238381254079006
# COV(citric acid,free sulfur dioxide): 0.19362977666595826
# COV(citric acid,total sulfur dioxide): 0.6229887080556064
# COV(citric acid,density): 5.411379637769594e-05
# COV(citric acid,pH): -0.0029923451312638557
# COV(citric acid,sulphates): 0.0008608829140398368
# COV(citric acid,alcohol): -0.011278238885878278
# COV(citric acid,quality): -0.0009870285830117548
# COV(residual sugar,fixed acidity): 0.381021813652795
# COV(residual sugar,volatile acidity): 0.032865333683183506
# COV(residual sugar,citric acid): 0.05782892645666931
# COV(residual sugar,residual sugar): 25.72577016438597
# COV(residual sugar,chlorides): 0.009827502056867173
# COV(residual sugar,free sulfur dioxide): 25.80057789900284
# COV(residual sugar,total sulfur dioxide): 86.53130297001032
# COV(residual sugar,density): 0.012727165342248768
# COV(residual sugar,pH): -0.14868366097842586
# COV(residual sugar,sulphates): -0.015434743486337131
# COV(residual sugar,alcohol): -2.8127403316263853
# COV(residual sugar,quality): -0.4383160938943709
# COV(chlorides,fixed acidity): 0.0004256255361050133
# COV(chlorides,volatile acidity): 0.000155277485703241
# COV(chlorides,citric acid): 0.00030238381254079006
# COV(chlorides,residual sugar): 0.009827502056867173
# COV(chlorides,chlorides): 0.00047733370982459226
# COV(chlorides,free sulfur dioxide): 0.03767449759033642
# COV(chlorides,total sulfur dioxide): 0.1846874888734888
# COV(chlorides,density): 1.6807535179787314e-05
# COV(chlorides,pH): -0.00029836485542560575
# COV(chlorides,sulphates): 4.1796868909082e-05
# COV(chlorides,alcohol): -0.009684235023156624
# COV(chlorides,quality): -0.0040621055899341865
# COV(free sulfur dioxide,fixed acidity): -0.7089186423667687
# COV(free sulfur dioxide,volatile acidity): -0.16630045911893623
# COV(free sulfur dioxide,citric acid): 0.19362977666595826
# COV(free sulfur dioxide,residual sugar): 25.80057789900284
# COV(free sulfur dioxide,chlorides): 0.03767449759033642
# COV(free sulfur dioxide,free sulfur dioxide): 289.24271999931955
# COV(free sulfur dioxide,total sulfur dioxide): 444.86589094680755
# COV(free sulfur dioxide,density): 0.014965531731955133
# COV(free sulfur dioxide,pH): -0.0015865548135610042
# COV(free sulfur dioxide,sulphates): 0.11493793418408597
# COV(free sulfur dioxide,alcohol): -5.234508673696522
# COV(free sulfur dioxide,quality): 0.12287824988974562
# COV(total sulfur dioxide,fixed acidity): 3.266013392629699
# COV(total sulfur dioxide,volatile acidity): 0.3823539031238282
# COV(total sulfur dioxide,citric acid): 0.6229887080556064
# COV(total sulfur dioxide,residual sugar): 86.53130297001032
# COV(total sulfur dioxide,chlorides): 0.1846874888734888
# COV(total sulfur dioxide,free sulfur dioxide): 444.86589094680755
# COV(total sulfur dioxide,total sulfur dioxide): 1806.0854908480983
# COV(total sulfur dioxide,density): 0.0673520256172624
# COV(total sulfur dioxide,pH): 0.014894217157645185
# COV(total sulfur dioxide,sulphates): 0.6526445768957304
# COV(total sulfur dioxide,alcohol): -23.476604602796375
# COV(total sulfur dioxide,quality): -6.5767463483989035
# COV(density,fixed acidity): 0.000669677255776885
# COV(density,volatile acidity): 8.173932688766277e-06
# COV(density,citric acid): 5.411379637769594e-05
# COV(density,residual sugar): 0.012727165342248768
# COV(density,chlorides): 1.6807535179787314e-05
# COV(density,free sulfur dioxide): 0.014965531731955133
# COV(density,total sulfur dioxide): 0.0673520256172624
# COV(density,density): 8.945524185781191e-06
# COV(density,pH): -4.226860806271931e-05
# COV(density,sulphates): 2.5427472403542187e-05
# COV(density,alcohol): -0.002871430362487801
# COV(density,quality): -0.0008135274381953839
# COV(pH,fixed acidity): -0.05426482595364051
# COV(pH,volatile acidity): -0.00048575309397266787
# COV(pH,citric acid): -0.0029923451312638557
# COV(pH,residual sugar): -0.14868366097842586
# COV(pH,chlorides): -0.00029836485542560575
# COV(pH,free sulfur dioxide): -0.0015865548135610042
# COV(pH,total sulfur dioxide): 0.014894217157645185
# COV(pH,density): -4.226860806271931e-05
# COV(pH,pH): 0.022801181084109688
# COV(pH,sulphates): 0.0026875229690797434
# COV(pH,alcohol): 0.022565052188878835
# COV(pH,quality): 0.013296600038373177
# COV(sulphates,fixed acidity): -0.0016509922909276956
# COV(sulphates,volatile acidity): -0.0004109902309336311
# COV(sulphates,citric acid): 0.0008608829140398368
# COV(sulphates,residual sugar): -0.015434743486337131
# COV(sulphates,chlorides): 4.1796868909082e-05
# COV(sulphates,free sulfur dioxide): 0.11493793418408597
# COV(sulphates,total sulfur dioxide): 0.6526445768957304
# COV(sulphates,density): 2.5427472403542187e-05
# COV(sulphates,pH): 0.0026875229690797434
# COV(sulphates,sulphates): 0.01302470597451644
# COV(sulphates,alcohol): -0.002448356078041467
# COV(sulphates,quality): 0.005425450686760576
# COV(alcohol,fixed acidity): -0.12553282191892606
# COV(alcohol,volatile acidity): 0.00839972308554453
# COV(alcohol,citric acid): -0.011278238885878278
# COV(alcohol,residual sugar): -2.8127403316263853
# COV(alcohol,chlorides): -0.009684235023156624
# COV(alcohol,free sulfur dioxide): -5.234508673696522
# COV(alcohol,total sulfur dioxide): -23.476604602796375
# COV(alcohol,density): -0.002871430362487801
# COV(alcohol,pH): 0.022565052188878835
# COV(alcohol,sulphates): -0.002448356078041467
# COV(alcohol,alcohol): 1.5144269817873466
# COV(alcohol,quality): 0.474726368777322
# COV(quality,fixed acidity): -0.08494730942928613
# COV(quality,volatile acidity): -0.01738244046216911
# COV(quality,citric acid): -0.0009870285830117548
# COV(quality,residual sugar): -0.4383160938943709
# COV(quality,chlorides): -0.0040621055899341865
# COV(quality,free sulfur dioxide): 0.12287824988974562
# COV(quality,total sulfur dioxide): -6.5767463483989035
# COV(quality,density): -0.0008135274381953839
# COV(quality,pH): 0.013296600038373177
# COV(quality,sulphates): 0.005425450686760576
# COV(quality,alcohol): 0.474726368777322
# COV(quality,quality): 0.7843556854710528

# %% [markdown]
# Above we can see:
# - **Positive Covarience** : when one value increase the other increases as well
# - **Negative Covarience** : When one value increase the other decreases
# - **0 Covarience** : not much effect of one or another
# (value won't be exaclty equal to 0, so sufficiently low values can be taken as 0)
#
#
# If we further divide the covariance values $ \text{COV}(X, Y) $ by the product of the standard deviations of $ X $ and $ Y $, we obtain the Pearson Correlation Coefficient. This coefficient provides information about the strength and direction of the linear relationship between the two variables.
#
# - **Strength**: The higher the absolute value of this coefficient, the more strongly the variables follow a linear relationship. For example, a coefficient close to 1 or -1 indicates a strong linear relationship.
#
# - **Direction**: A positive coefficient means that as one variable increases, the other variable also tends to increase (both increase together). A negative coefficient means that as one variable increases, the other variable tends to decrease (one increases while the other decreases).

# %%
for col1 in data.columns:
    for col2 in data.columns:
        print(f"COV({col1},{col2}):",(data[col1].cov(data[col2])/(data[col1].std() * data[col2].std())))
# Out:
# COV(fixed acidity,fixed acidity): 0.9999999999999997
# COV(fixed acidity,volatile acidity): -0.02269729014664708
# COV(fixed acidity,citric acid): 0.2891806976936752
# COV(fixed acidity,residual sugar): 0.08902070136217158
# COV(fixed acidity,chlorides): 0.023085643656347788
# COV(fixed acidity,free sulfur dioxide): -0.04939585908117314
# COV(fixed acidity,total sulfur dioxide): 0.09106975615864087
# COV(fixed acidity,density): 0.2653310138391866
# COV(fixed acidity,pH): -0.425858290991382
# COV(fixed acidity,sulphates): -0.01714298502113732
# COV(fixed acidity,alcohol): -0.12088112319453301
# COV(fixed acidity,quality): -0.11366283071301789
# COV(volatile acidity,fixed acidity): -0.02269729014664708
# COV(volatile acidity,volatile acidity): 1.0
# COV(volatile acidity,citric acid): -0.14947181064857515
# COV(volatile acidity,residual sugar): 0.06428606009099527
# COV(volatile acidity,chlorides): 0.07051157147938474
# COV(volatile acidity,free sulfur dioxide): -0.09701193927796005
# COV(volatile acidity,total sulfur dioxide): 0.08926050355177843
# COV(volatile acidity,density): 0.027113845462434297
# COV(volatile acidity,pH): -0.03191536827348891
# COV(volatile acidity,sulphates): -0.035728146905814724
# COV(volatile acidity,alcohol): 0.06771794277504412
# COV(volatile acidity,quality): -0.19472296892113428
# COV(citric acid,fixed acidity): 0.2891806976936752
# COV(citric acid,volatile acidity): -0.14947181064857515
# COV(citric acid,citric acid): 1.0
# COV(citric acid,residual sugar): 0.09421162429049391
# COV(citric acid,chlorides): 0.11436444838681831
# COV(citric acid,free sulfur dioxide): 0.09407722101469615
# COV(citric acid,total sulfur dioxide): 0.12113079766441819
# COV(citric acid,density): 0.14950257057002278
# COV(citric acid,pH): -0.16374821140062368
# COV(citric acid,sulphates): 0.062330940285232866
# COV(citric acid,alcohol): -0.07572873005717937
# COV(citric acid,quality): -0.009209090883975415
# COV(residual sugar,fixed acidity): 0.08902070136217158
# COV(residual sugar,volatile acidity): 0.06428606009099527
# COV(residual sugar,citric acid): 0.09421162429049391
# COV(residual sugar,residual sugar): 1.000000000000001
# COV(residual sugar,chlorides): 0.08868453594122555
# COV(residual sugar,free sulfur dioxide): 0.2990983536935181
# COV(residual sugar,total sulfur dioxide): 0.4014393111599249
# COV(residual sugar,density): 0.8389664549045831
# COV(residual sugar,pH): -0.19413345399025594
# COV(residual sugar,sulphates): -0.026664365853858354
# COV(residual sugar,alcohol): -0.45063122203172873
# COV(residual sugar,quality): -0.09757682889469316
# COV(chlorides,fixed acidity): 0.023085643656347788
# COV(chlorides,volatile acidity): 0.07051157147938474
# COV(chlorides,citric acid): 0.11436444838681831
# COV(chlorides,residual sugar): 0.08868453594122555
# COV(chlorides,chlorides): 1.0000000000000016
# COV(chlorides,free sulfur dioxide): 0.10139235214132997
# COV(chlorides,total sulfur dioxide): 0.19891029964505555
# COV(chlorides,density): 0.25721132043643513
# COV(chlorides,pH): -0.0904394559759817
# COV(chlorides,sulphates): 0.016762883708175743
# COV(chlorides,alcohol): -0.3601887121081628
# COV(chlorides,quality): -0.20993441094676055
# COV(free sulfur dioxide,fixed acidity): -0.04939585908117314
# COV(free sulfur dioxide,volatile acidity): -0.09701193927796005
# COV(free sulfur dioxide,citric acid): 0.09407722101469615
# COV(free sulfur dioxide,residual sugar): 0.2990983536935181
# COV(free sulfur dioxide,chlorides): 0.10139235214132997
# COV(free sulfur dioxide,free sulfur dioxide): 0.9999999999999998
# COV(free sulfur dioxide,total sulfur dioxide): 0.6155009650098363
# COV(free sulfur dioxide,density): 0.29421041088431
# COV(free sulfur dioxide,pH): -0.0006177961403311526
# COV(free sulfur dioxide,sulphates): 0.05921724582526293
# COV(free sulfur dioxide,alcohol): -0.2501039414835315
# COV(free sulfur dioxide,quality): 0.008158067123436065
# COV(total sulfur dioxide,fixed acidity): 0.09106975615864087
# COV(total sulfur dioxide,volatile acidity): 0.08926050355177843
# COV(total sulfur dioxide,citric acid): 0.12113079766441819
# COV(total sulfur dioxide,residual sugar): 0.4014393111599249
# COV(total sulfur dioxide,chlorides): 0.19891029964505555
# COV(total sulfur dioxide,free sulfur dioxide): 0.6155009650098363
# COV(total sulfur dioxide,total sulfur dioxide): 1.0000000000000002
# COV(total sulfur dioxide,density): 0.5298813238786111
# COV(total sulfur dioxide,pH): 0.002320971768277856
# COV(total sulfur dioxide,sulphates): 0.13456236692980905
# COV(total sulfur dioxide,alcohol): -0.4488921020613415
# COV(total sulfur dioxide,quality): -0.17473721759706284
# COV(density,fixed acidity): 0.2653310138391866
# COV(density,volatile acidity): 0.027113845462434297
# COV(density,citric acid): 0.14950257057002278
# COV(density,residual sugar): 0.8389664549045831
# COV(density,chlorides): 0.25721132043643513
# COV(density,free sulfur dioxide): 0.29421041088431
# COV(density,total sulfur dioxide): 0.5298813238786111
# COV(density,density): 0.9999999999999997
# COV(density,pH): -0.09359149345524456
# COV(density,sulphates): 0.07449314851167602
# COV(density,alcohol): -0.7801376214255578
# COV(density,quality): -0.3071233127347305
# COV(pH,fixed acidity): -0.425858290991382
# COV(pH,volatile acidity): -0.03191536827348891
# COV(pH,citric acid): -0.16374821140062368
# COV(pH,residual sugar): -0.19413345399025594
# COV(pH,chlorides): -0.0904394559759817
# COV(pH,free sulfur dioxide): -0.0006177961403311526
# COV(pH,total sulfur dioxide): 0.002320971768277856
# COV(pH,density): -0.09359149345524456
# COV(pH,pH): 0.9999999999999991
# COV(pH,sulphates): 0.1559514972796521
# COV(pH,alcohol): 0.12143209874912933
# COV(pH,quality): 0.09942724573666425
# COV(sulphates,fixed acidity): -0.01714298502113732
# COV(sulphates,volatile acidity): -0.035728146905814724
# COV(sulphates,citric acid): 0.062330940285232866
# COV(sulphates,residual sugar): -0.026664365853858354
# COV(sulphates,chlorides): 0.016762883708175743
# COV(sulphates,free sulfur dioxide): 0.05921724582526293
# COV(sulphates,total sulfur dioxide): 0.13456236692980905
# COV(sulphates,density): 0.07449314851167602
# COV(sulphates,pH): 0.1559514972796521
# COV(sulphates,sulphates): 0.9999999999999999
# COV(sulphates,alcohol): -0.01743277185595176
# COV(sulphates,quality): 0.05367787713279205
# COV(alcohol,fixed acidity): -0.12088112319453301
# COV(alcohol,volatile acidity): 0.06771794277504412
# COV(alcohol,citric acid): -0.07572873005717937
# COV(alcohol,residual sugar): -0.45063122203172873
# COV(alcohol,chlorides): -0.3601887121081628
# COV(alcohol,free sulfur dioxide): -0.2501039414835315
# COV(alcohol,total sulfur dioxide): -0.4488921020613415
# COV(alcohol,density): -0.7801376214255578
# COV(alcohol,pH): 0.12143209874912933
# COV(alcohol,sulphates): -0.01743277185595176
# COV(alcohol,alcohol): 1.0000000000000018
# COV(alcohol,quality): 0.43557471546137344
# COV(quality,fixed acidity): -0.11366283071301789
# COV(quality,volatile acidity): -0.19472296892113428
# COV(quality,citric acid): -0.009209090883975415
# COV(quality,residual sugar): -0.09757682889469316
# COV(quality,chlorides): -0.20993441094676055
# COV(quality,free sulfur dioxide): 0.008158067123436065
# COV(quality,total sulfur dioxide): -0.17473721759706284
# COV(quality,density): -0.3071233127347305
# COV(quality,pH): 0.09942724573666425
# COV(quality,sulphates): 0.05367787713279205
# COV(quality,alcohol): 0.43557471546137344
# COV(quality,quality): 1.0000000000000027

# %% [markdown]
# #### We covered basic statistics tools, which help us understand data through numbers. But looking at all these numbers can quickly fry your brain. To make sense of data in a visual way, we use Exploratory Data Analysis (EDA). EDA involves creating charts and graphs to visually explore and understand data patterns and relationships.
#
# ##### Note: further details in pen and paper statistics, there are still many more measure we can use to further understand what a dataset say i will slowly be covering those.
